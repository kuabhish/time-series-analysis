# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import time
from collections import deque
from random import random
from ipykernel import kernelapp as app
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, ExponentialSmoothing
from numpy.random import choice
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ## create a basic data

# %%
x = [ 1,2,3,4,5,6,   1,2,3,4,5,6,  1,2,3,4,5,6,   1,2,3,4,5,6 ]
len(x)
# Out:
# 24

# %%
def generate_random(lb = -0.1, ub = 0.1):
    return (ub-lb)*(np.random.random()) + lb

# %%
generate_random()
# Out:
# 0.01907174331872448

# %%
# plt.plot(x)
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(x, 'y')
# plt.plot([3], [6] , 'r')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def datagen():
  x = [ 1,2,3,4,5,6 ]
  if len(x) >0:
    for y in x:
      yield y
      x.append(y)

# %%
def single_exponential_smoothing(x , a=0.5):
    res = [ np.nan , x[0]]
    for i in range( 2 , len(x)+1 ):
        res.append( a*x[i-1] + (1-a)*res[i-1] )
    return res

# %%
single_exponential_smoothing(np.arange(1,3))
# Out:
# [nan, 1, 1.5]

# %%
def holtwinters(x):
    model = ExponentialSmoothing(list(x) , trend='add', seasonal_periods=4)
#     model = SimpleExpSmoothing(list(x) )
    model_fit = model.fit()
    yhat = model_fit.predict()
    return yhat[0]
#     print(yhat[0])

# %%
# %matplotlib notebook

fig, ax = plt.subplots(figsize=(10,5))
max_len = 100
original = deque(maxlen=max_len)
created = deque(maxlen=max_len)
good_points = {}
anomalous_points = {}

index = 0
ind = []
for i in datagen():
    ind.append(index)
    
    cho = choice(np.arange(1,10))
    if index%cho == 0:
        original.append(i+generate_random(lb=-1, ub=1))
    else:
        original.append(i)
    created.append(single_exponential_smoothing(original)[-1])
    
#     if index >20:
#         created.append(holtwinters(original))
# #         plt.plot(ind , created , 'g', label = 'predicted')
#     else:
#         created.append(0)
    
    ax.clear()
    plt.plot(ind , original , 'y', label='original')
    plt.plot(ind , created , 'g', label = 'predicted')
    
    if np.abs(created[-1]- original[-1])>1:
        anomalous_points[index] = original[-1]
    else:
        good_points[index] = original[-1]
    
    for i in anomalous_points.keys():
        plt.plot(i , anomalous_points[i], 'ro')
                
                

    plt.legend()
    fig.canvas.draw()
    fig.show()
    plt.pause(.1)
    index+=1
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-e0cadddc47c7> in <module>
#      41
#      42     plt.legend()
# ---> 43     fig.canvas.draw()
#      44     fig.show()
#      45     plt.pause(.1)
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1213         # the actual bbox
#    1214
# -> 1215         self._update_label_position(renderer)
#    1216
#    1217         self.label.draw(renderer)
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2012         # get bounding boxes for this axis and any siblings
#    2013         # that have been set by `fig.align_xlabels()`
# -> 2014         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2015
#    2016         x, y = self.label.get_position()
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1996         # if we want to align labels from other axes:
#    1997         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 1998             ticks_to_draw = axx.xaxis._update_ticks()
#    1999             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2000             bboxes.extend(tlb)
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/ticker.py in __call__(self)
#    2079     def __call__(self):
#    2080         vmin, vmax = self.axis.get_view_interval()
# -> 2081         return self.tick_values(vmin, vmax)
#    2082
#    2083     def tick_values(self, vmin, vmax):
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2087         vmin, vmax = mtransforms.nonsingular(
#    2088             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2089         locs = self._raw_ticks(vmin, vmax)
#    2090
#    2091         prune = self._prune
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2026         if self._nbins == 'auto':
#    2027             if self.axis is not None:
# -> 2028                 nbins = np.clip(self.axis.get_tick_space(),
#    2029                                 max(1, self._min_n_ticks - 1), 9)
#    2030             else:
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2181         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2182         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2183         tick = self._get_tick(True)
#    2184         # There is a heuristic here that the aspect ratio of tick text
#    2185         # is no more than 3:1
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
# --> 162         self.label2 = self._get_text2()
#     163
#     164         self.gridline.set_visible(gridOn)
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/axis.py in _get_text2(self)
#     450             color=self._labelcolor,
#     451             verticalalignment=vert,
# --> 452             horizontalalignment=horiz,
#     453             )
#     454         t.set_transform(trans)
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     166         self._linespacing = linespacing
#     167         self.set_rotation_mode(rotation_mode)
# --> 168         self.update(kwargs)
#     169
#     170     def update(self, kwargs):
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/text.py in update(self, kwargs)
#     175         sentinel = object()  # bbox can be None, so use another sentinel.
#     176         bbox = kwargs.pop("bbox", sentinel)
# --> 177         super().update(kwargs)
#     178         if bbox is not sentinel:
#     179             self.set_bbox(bbox)
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     971                 return func(v)
#     972
# --> 973         with cbook._setattr_cm(self, eventson=False):
#     974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#
# ~/anaconda3/envs/my_env/lib/python3.7/contextlib.py in helper(*args, **kwds)
#     237     @wraps(func)
#     238     def helper(*args, **kwds):
# --> 239         return _GeneratorContextManager(func, args, kwds)
#     240     return helper
#     241
#
# ~/anaconda3/envs/my_env/lib/python3.7/contextlib.py in __init__(self, func, args, kwds)
#      79     """Shared functionality for @contextmanager and @asynccontextmanager."""
#      80
# ---> 81     def __init__(self, func, args, kwds):
#      82         self.gen = func(*args, **kwds)
#      83         self.func, self.args, self.kwds = func, args, kwds
#
# KeyboardInterrupt:

# %%
# model = ExponentialSmoothing(list(original)[:2], trend='add', seasonal_periods=4)
# model_fit = model.fit()
# yhat = model_fit.predict()
# print(yhat[0])

# %%
# original

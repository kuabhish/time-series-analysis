# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils

# %%
df = pd.read_csv('../data/datatraining.txt')
df.shape
# Out:
# (8143, 7)

# %%
df.head()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %%
# df.Occupancy.value_counts()
col = 'HumidityRatio'

# %%
plt.plot( df.index, df[col] )

# %%
plt.plot( df.index, df[col] )
plt.plot( df.index, utils.average(df[col]) )

# %%
# size = 100
# plt.plot( df.index[:size] , df[col][:size] )
# plt.plot( df.index[:size] , utils.moving_average(df[col], 3 )[:size] )

# %%
from scipy.signal import correlate

# %%
x = [ 1,2,3,4,5,6,   1,2,3,4,5,6,  1,2,3,4,5,6,   1,2,3,4,5,6 ]
len(x)
# Out:
# 24

# %%
x = df[col]

# %%
plt.plot(x)

# %%
ac = np.correlate( x , x , mode='full' )
ac[ac.shape[0]//2:]
# Out:
# array([1.27399981e-01, 1.27371936e-01, 1.27344318e-01, ...,
#        8.05323558e-05, 5.37885149e-05, 2.68985542e-05])

# %%
# figure = plt.figure(figsize=(20,10))
plt.plot(ac[ac.shape[0]//2:])

# %%
import scipy
from scipy import signal
signal.find_peaks(ac[ac.shape[0]//2:])
# Out:
# (array([], dtype=int64), {})

# %%
# ac[ac.shape[0]//2:][1141]

# %%
plt.plot(x , label='original' )
plt.plot( utils.double_exponential_smoothing(x)[0] , label = 'predicted' )
plt.grid()
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-9ba6361d7d20> in <module>
#       1 plt.plot(x , label='original' )
# ----> 2 plt.plot( utils.double_exponential_smoothing(x)[0] , label = 'predicted' )
#       3 plt.grid()
#       4 plt.legend()
#
# ~/Documents/Automl/time-series-analysis/notebooks/utils.py in double_exponential_smoothing(x, a, g)
#      22
#      23 def double_exponential_smoothing(x , a=0.5, g=0.5 ):
# ---> 24   res = [x[0]]
#      25   s = [x[0]]
#      26   b = [np.mean(np.sum(x[1:4]) - np.sum(x[0:3]) )]
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
x=df[col]

# %%
x.shape
# Out:
# (8143,)

# %%
from statsmodels.tsa.stattools import acf

# %%
# sorted(np.correlate( x , x , mode='full' ), reverse= True)

# %%
correlate( x,x )
# Out:
# array([  6,  17,  32,  50,  70,  91,  82,  84,  96, 117, 146, 182, 158,
#        151, 160, 184, 222, 273, 234, 218, 224, 251, 298, 364, 298, 251,
#        224, 218, 234, 273, 222, 184, 160, 151, 158, 182, 146, 117,  96,
#         84,  82,  91,  70,  50,  32,  17,   6])
